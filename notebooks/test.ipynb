# %% [markdown]
# ### import stuff

# %%
import cv2
from ultralytics import YOLO  # type:ignore

# %% [markdown]
# Get the model

# %%
from pathlib import Path
import sys

root = Path.cwd()
print(root)

model_path = f"{root}/models/yolo11n.pt"
print(model_path)
# Out:
# d:\Coding\zone-detector\notebooks
# d:\Coding\zone-detector\notebooks/models/yolo11n.pt

# %%
# %cd ..
from config import constants as c
# Out:
# d:\Coding\zone-detector

# %%
import cv2
cam = cv2.VideoCapture(c.RAW_VIDEO_PATH)  #type:ignore
print(cam.isOpened())
# Out:
# True

# %%
model = YOLO(c.YOLO11N_PATH, task = "detect", verbose = False)

# %%
def mouse_callback(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        print(f"x: {x}, y: {y}")

# %%
# while True:
#     ret, frame = cam.read()
#     if not ret:
#         print("Can't get frame")
#         break

#     results = model(frame,classes = [0], imgsz = c.HALF_IMAGE_SIZE)
#     result = list(results)[0]
    
#     annotated_frame = result.plot()
#     wintitle = "Detect person"
#     cv2.imshow(wintitle, annotated_frame)

#     cv2.waitKey(1)

#     if cv2.getWindowProperty(wintitle, cv2.WND_PROP_VISIBLE) < 1:
#         break

# cam.release()
# cv2.destroyAllWindows()
import time, numpy as np

ret, raw_frame = cam.read()

h, w = raw_frame.shape[:2]
f = w
mtx = np.array([
    [f, 0, w/2],
    [0, f, h/2],
    [0, 0, 1]
])
dist = np.array([-0.35, 0.05, 0.0, 0.0, 0.0], dtype = np.float32).reshape(1,5)
frame = cv2.undistort(raw_frame, mtx, dist)

time.sleep(2)
if not ret:
    print("can't get frame")
else: 
    print("could get frame")

WINDOW_TITLE = "Zone Detector"
cv2.namedWindow(WINDOW_TITLE)
cv2.setMouseCallback(WINDOW_TITLE, mouse_callback)

cv2.imshow(WINDOW_TITLE,frame)
cv2.waitKey(0)



cam.release()
# Out:
# could get frame
# x: 1911, y: 1048
# x: 5, y: 8
# x: 1919, y: 1003
# x: 1919, y: 1005
# x: 1919, y: 1002
# x: 1917, y: 1076
# x: 1917, y: 1076
# x: 1917, y: 1076
# x: 1917, y: 1076

# %%
print(w,h)
# Out:
# 1920 1080

# %% [markdown]
# The Code below is meant to be a TODO list

# %%
''' 
DONE:
finish flags of prepare_model
run_test prepare_model
watch videos -> pick videos, specify the zones to detect =>> source.mp4
make a constant RAW_VIDEO_PATH

TODO:
undistort the cam
in notebooks, make a point finder

make zone_detector.py? (ZoneDetector class that wraps around the model)
'''
# Out:
# ' \nDONE:\nfinish flags of prepare_model\nrun_test prepare_model\nwatch videos -> pick videos, specify the zones to detect =>> source.mp4\nmake a constant RAW_VIDEO_PATH\n\nTODO:\nundistort the cam\nin notebooks, make a point finder\n\nmake zone_detector.py? (ZoneDetector class that wraps around the model)\n'
